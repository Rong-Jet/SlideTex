# %%
# %pip install pdf2image==1.17.0 openai==1.30.1 tiktoken==0.7.0 python-dotenv==1.0.1 PyPDF2==3.0.1

# %%
# %conda install -c conda-forge poppler==24.04.0

# %%
import tempfile
import os
import json
import base64
import requests
import tempfile
import subprocess
import PyPDF2
from dotenv import load_dotenv
from openai import OpenAI
from IPython.display import display, Math, Markdown
from pdf2image import convert_from_path, convert_from_bytes
from pdf2image.exceptions import (
    PDFInfoNotInstalledError,
    PDFPageCountError,
    PDFSyntaxError
)

load_dotenv('NotesFromSlides.env')
api_key = os.getenv('OPENAI_API_KEY')

# %%
def pdf_to_images(input_path, output_path):
    slide_numbers = []
    images = convert_from_path(input_path)
    for i, image in enumerate(images):
        image.save(f"{output_path}/page_{i+1}.png", "PNG")
        slide_numbers.append(i+1)
    return slide_numbers

# %%
def encode_image(image_path):
  with open(image_path, "rb") as image_file:
    return base64.b64encode(image_file.read()).decode('utf-8')

# %%
def clean_vision_message(response):
  return response.json()['choices'][0]['message']['content']

# %%
def get_text_from_image(image_path, theme):
  # Getting the base64 string
  base64_image = encode_image(image_path)

  headers = {
    "Content-Type": "application/json",
  "Authorization": f"Bearer {api_key}"
  }

  payload = {
    "model": "gpt-4o",
    "messages": [
      {
        "role": "user",
        "content": [
          {
            "type": "text",
            "text": f"""
            You are a tutor chatbot helping university students understand PDF slides from their lecturer.  
            The theme of the slidecast is {theme}.

            Firstly, decide if the slide contains RELEVANT INFORMATION WORTH EXPLAINING.
            If the given slide has TOO LITTLE RELEVANT INFORMATION (e.g. title slides, video thumbnails, illustrations containing minimal information) return ONLY the message "NO RELEVANT INFORMATION."
            If the given slide is RELEVANT to the theme (e.g. practical examples of the theme, statistics, relevant explanations) give an output based on the following instructions:

            1. Provide a SHORT and CONCISE summary of the slide content.
            2. Explain the CONCEPTS, TERMS, DIAGRAMS, GRAPHS, and DATA that are relevant to the theme.
            3. If needed, include a NOTES section for additional information.
            
            Follow the instructions carefully, non-conformity will result in termination.
            """
          },
          {
            "type": "image_url",
            "image_url": {
              "url": f"data:image/jpeg;base64,{base64_image}"
            }
          }
        ]
      }
    ],
    "max_tokens": 900
  }

  vision_response = requests.post("https://api.openai.com/v1/chat/completions", headers=headers, json=payload)
  return clean_vision_message(vision_response)

# %%
def compare_vision_message(message1, message2):
  client = OpenAI()

  response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
      {"role": "system", "content": "You are a bot designed to compare the content of messages."},
      {"role": "user", "content": f"""
      Follow these instructions to evaluate the two messages:
      
      1. Read both messages carefully.
      2. Decide if there is an overlap in the content of the two messages.
      3. If there is an overlap of more than half of the content, return the message "OVERLAP IN CONTENT" and PROVIDE A SUMMARY of the overlapping content.
      4. Otherwise, return the message "PASS".
      
      Here is the first message:"
      {message1}
      "
      
      Here is the second message:"
      {message2}
      "
      
      Follow the instructions carefully, non-conformity will result in termination.
      """},
    ]
  )
  if "OVERLAP IN CONTENT" in response.choices[0].message.content:
    return response.choices[0].message.content
  else:
    return "PASS"

# %%
def remove_overlap(message, overlap):
  client = OpenAI()

  response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
      {"role": "system", "content": "You are a bot designed to edit the content of messages."},
      {"role": "user", "content": f"""
      Follow these instructions to edit the message:
      
      1. Read the message and the overlapping content carefully.
      2. Remove the overlapping content from the message.
      3. Ensure the message is coherent and makes sense.
      
      Here is the message:"
      {message}
      "
      
      Here is the overlapping content:"
      {overlap}
      "
      
      Follow the instructions carefully, non-conformity will result in termination.
      """},
    ]
  )
  return response.choices[0].message.content

# %%
def clean_completions_message(response):
    return response.choices[0].message.content

# %%
def get_formatted_output_from_text(message):
  client = OpenAI()

  response = client.chat.completions.create(
    model="gpt-4o",
    messages=[
      {"role": "system", "content": "You are a bot designed to help structure and create LaTeX notes from unstructured text."},
      {"role": "user", "content": f"""
      Follow these rules to create a LaTeX document from the given text:
      
      1. Format the output in XeLaTeX parsable syntax, ensuring proper use of sections, subsections, and formatting commands.
      2. Make sure that the output can be DIRECTLY be taken and parsed by a LaTeX compiler.
      3. Do NOT include external graphics (e.g. references to include another png) in the output.
      4. Use `\\textbf{{}}` for bold text. Use `\\textit{{}}` for italics. You are to decide where to use bold and italics based on the context.
      5. Make sure to ESCAPE special characters that are reserved in LaTeX, such as `#`, `$`, `%`, `^`, `&`, `_`, `~`, and `\\`.
      6. ONLY the section and subsections titles are fixed and should not be changed. The rest is VARIABLE and can be changed based on the number of points, their hierarchy and their structure.
      7. First level points under subsections should NEITHER be in a list format, NOR be separated by empty lines, but rather ONLY be separated by newlines (\\\\) as shown in the example.
      8. Second and further level points should be in a list format, as shown in the example.
      9. Make sure that after each list, there is NO empty line, as shown in the example.
      10. DO NOT INCLUDE the preamble, START FROM \\begin{{document}} and END AT \\end{{document}}.
      11. ALWAYS include \\maketitle after \\begin{{document}}.
      
      Use the following LaTeX example just as a reference, not as a hard template:
      
      \\begin{{document}}

      \\maketitle

      \\section*{{Summary}}

      [text]

      \\section*{{Explanations}}

      \\subsection*{{Concepts and Terms}}

      [text]: [text]\\\\
      [text]: [text]

      \\subsection*{{Diagrams and Data}}

      \\textbf{{[text]}}
          \\begin{{itemize}}
              \\item [text]
              \\item [text]
          \\end{{itemize}}
      \\textbf{{[text]}}
          \\begin{{itemize}}
              \\item [text]
              \\item [text]
          \\end{{itemize}}

      \\subsection*{{Notes:}}

      - [text]\\\\
      - [text]

      \\end{{document}}
      
      Here is the unstructured text:
      
      {message}
      
      Follow the instructions carefully, non-conformity will result in TERMINATION.
      """},
    ]
  )
  return clean_completions_message(response)

# %%
def shorten_output(string):
    start_index = string.find("\\documentclass{article}")
    end_index = string.rfind("\\end{document}")

    if start_index != -1 and end_index != -1:
        return string[start_index:end_index + len("\\end{document}")]
    else:
        return string

# %%
def create_LaTeX_from_formatted_output(output, index, theme, output_directory):
    # Join the output with the latex template
    content = shorten_output(output)
    latex_template = f"""
    \\documentclass[12pt]{{article}}

    % Essential packages for compatibility and error prevention
    \\usepackage{{lmodern}}
    \\usepackage{{fixltx2e}}
    \\usepackage{{fontspec}}

    % Mathematics packages
    \\usepackage{{amsmath}}
    \\usepackage{{amssymb}}
    \\usepackage{{amsfonts}}
    \\usepackage{{mathtools}}

    % Other mathematics-related packages
    \\usepackage{{bm}}
    \\usepackage{{physics}}
    \\AtBeginDocument{{\\RenewCommandCopy\\qty\\SI}}
    \\usepackage{{cancel}}
    \\usepackage{{commath}}
    \\usepackage{{braket}}
    \\usepackage{{xfrac}}

    % Chemical notation packages
    \\usepackage{{chemformula}}
    \\usepackage[version=4]{{mhchem}}

    % Units and scientific notation
    \\usepackage{{siunitx}}
    \\AtBeginDocument{{\\RenewCommandCopy\\qty\\SI}} % Use siunitx's \\qty definition

    % Greek letters
    \\usepackage{{upgreek}}
    \\usepackage{{textgreek}}

    % General symbols
    \\usepackage{{gensymb}}

    % Space management
    \\usepackage{{xspace}}

    % Typography improvements
    \\usepackage{{microtype}}

    % Load unicode-math to use Unicode characters in math
    \\usepackage{{unicode-math}}

    % Set the main font and math font to STIX Two fonts
    \\setmainfont{{STIX Two Text}}
    \\setmathfont{{STIX Two Math}}

    \\title{{Summary and Explanation of Slide {index} on {theme}}}
    \\author{{}} % Removes the author
    \\date{{}} % Removes the date
    
    {content}
    """

    # Specify the directory where you want to save the files
    os.makedirs(output_directory, exist_ok=True)

    # Define file path
    latex_file_path = os.path.join(output_directory, f'document_{index}.tex')
    txt_file_path = os.path.join(output_directory, f'document_{index}.txt')

    # Write the LaTeX content to the file
    with open(latex_file_path, 'w') as f:
        f.write(latex_template)
        
    # Write the text content to the file
    with open(txt_file_path, 'w') as f:
        f.write(content)
        
    print(f"The LaTeX file has been created at: {latex_file_path}")

# %%
def remove_skipped_slides(slides_to_convert, skipped_slides):
    return [slide for slide in slides_to_convert if slide not in skipped_slides]

# %%
def combine_pdfs(input_directory, output_directory, output_filename='combined.pdf'):
    # Get a list of all PDF files in the input directory
    pdf_files = [f for f in os.listdir(input_directory) if f.endswith('.pdf')]
    
    def sort_pdf_files(pdf_files):
        def key_func(file):
            try:
                # Extract the index from the file name assuming the format 'file_<index>.pdf'
                index = int(file.split('_')[1].split('.')[0])
            except (IndexError, ValueError):
                index = float('inf')  # Handle cases where the filename format is unexpected
            return index
        
        return sorted(pdf_files, key=key_func)
    
    pdf_files = sort_pdf_files(pdf_files)

    # Create a PdfMerger object
    merger = PyPDF2.PdfMerger()

    # Append each PDF file to the merger
    for pdf in pdf_files:
        merger.append(os.path.join(input_directory, pdf))

    # Write out the merged PDF to the output directory
    with open(os.path.join(output_directory, output_filename), 'wb') as output_file:
        merger.write(output_file)

    # Close the merger
    merger.close()

    print(f'All PDFs combined into {output_filename} in {output_directory}')

# %%
path_to_pdf = rf"C:\Users\ACER\Downloads\5_Dynamic_materials.pdf"
theme = "DYNAMIC MATERIALS"
path_to_tex = rf"C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials"
path_to_LaTeX = rf"C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\Temp_Test_File_Dynamic_Materials"

with tempfile.TemporaryDirectory() as temp_dir_images:
    slide_numbers = pdf_to_images(path_to_pdf, temp_dir_images)
    print("Slides converted to pngs.\n")

    skipped_slides = []
    overlapping_slides = []
    previous_message = None
    temp_comparison_message = None

    for i in slide_numbers:
        vision_message = get_text_from_image(temp_dir_images + rf"/page_{i}.png", theme)
        print(f"1. {vision_message}\n")
        if "NO RELEVANT INFORMATION" in vision_message:
            print("The slide is irrelevant.\n")
            skipped_slides.append(i)
            continue
        if previous_message is not None:
            print(f"2. Comparing slide {i-1} and slide {i}.\n")
            comparison_response = compare_vision_message(previous_message, vision_message)
            if "OVERLAP IN CONTENT" in comparison_response:
                print("There is an overlap in content.\n")
                overlapping_slides.append(f"{i-1}, {i}")
                overlap = comparison_response
                print(f"Overlap: \n{overlap}\n")
                temp_comparison_message = vision_message
                vision_message = remove_overlap(vision_message, overlap)
                print(f"New message: \n{vision_message}\n")
                previous_message = temp_comparison_message
            else:
                print("There is no overlap in content.\n")
                previous_message = vision_message
                temp_comparison_message = None
        else:
            print("2. No previous message to compare to.\n")
            previous_message = vision_message
        completions_message = get_formatted_output_from_text(vision_message)
        print(f"3. {completions_message}\n")
        create_LaTeX_from_formatted_output(completions_message, i, theme, path_to_tex)
        print("\n\n\n")
        
    print(f"Skipped slides: {skipped_slides}")
    print(f"Overlapping slides: {overlapping_slides}")
    pass
# Out:
# Slides converted to pngs.
#
# 1. NO RELEVANT INFORMATION.
#
# The slide is irrelevant.
#
# 1. ### Summary:
# This slide introduces the concept of self-assembly by providing a definition from Wikipedia.
#
# ### Explanation:
# **Self-assembly:**
# - **Definition:** The process where a disordered system of pre-existing components forms an organized structure or pattern due to specific, local interactions among the components, happening without external direction.
# - **Molecular self-assembly:** When the components involved are molecules.
#
# ### Relevant Concepts:
# - **Disordered system:** A system where the components are initially in a random or unordered state.
# - **Organized structure:** The final state where the components have formed a specific pattern or configuration.
# - **Local interactions:** Interactions among components in close proximity that drive the assembly process.
# - **Without external direction:** The process occurs naturally without the need for an external guiding force.
#
# ### Diagram:
# - **Top Image (Puzzle Pieces):** Represents the disordered system of components.
# - **Bottom Image (House Puzzle):** Represents the organized structure formed through self-assembly.
#
# ### Notes:
# - The concept of self-assembly is crucial in understanding how complex structures can spontaneously form in nature and technology, especially in nanotechnology and molecular biology.
#
# 2. No previous message to compare to.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# This slide introduces the concept of \textit{self-assembly} by providing a definition from Wikipedia.
#
# \section*{Explanation}
#
# \subsection*{Self-assembly}
#
# \textbf{Definition:} The process where a disordered system of pre-existing components forms an organized structure or pattern due to specific, local interactions among the components, happening without external direction.\\
# \textbf{Molecular self-assembly:} When the components involved are molecules.
#
# \subsection*{Relevant Concepts}
#
# \textbf{Disordered system:} A system where the components are initially in a random or unordered state.\\
# \textbf{Organized structure:} The final state where the components have formed a specific pattern or configuration.\\
# \textbf{Local interactions:} Interactions among components in close proximity that drive the assembly process.\\
# \textbf{Without external direction:} The process occurs naturally without the need for an external guiding force.
#
# \subsection*{Diagram}
#
# \textbf{Top Image (Puzzle Pieces)}
#     \begin{itemize}
#         \item Represents the disordered system of components.
#     \end{itemize}
# \textbf{Bottom Image (House Puzzle)}
#     \begin{itemize}
#         \item Represents the organized structure formed through self-assembly.
#     \end{itemize}
#
# \subsection*{Notes}
#
# - The concept of self-assembly is crucial in understanding how complex structures can spontaneously form in nature and technology, especially in nanotechnology and molecular biology.\\
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_2.tex
#
#
#
#
# 1. ### Summary:
# The slide explains the concept of self-assembly, categorizing it into static and dynamic types.
#
# ### Concepts and Terms:
# 1. **Self-assembly**: The process where components organize into ordered structures without external direction.
# 2. **Static self-assembly**: Refers to the formation of ordered states as the system reaches equilibrium, decreasing free energy (\(F = E - TS\)):
#     - \(E\): Enthalpy (total energy)
#     - \(S\): Entropy (measure of disorder)
#     - \(T\): Temperature
#
# 3. **Dynamic self-assembly**: Involves the organization of components into patterns that can evolve over time due to changes in component properties or external stimuli.
#
# ### Notes:
# - **Binding and Hydrophobicity**: Are given as examples of forces driving self-assembly. Binding involves attractive interactions while hydrophobicity refers to the tendency of non-polar substances to avoid water.
#
# 2. Comparing slide 2 and slide 3.
#
# There is an overlap in content.
#
# Overlap:
# OVERLAP IN CONTENT
#
# ### Summary of Overlapping Content:
# The concept of self-assembly is addressed in both messages, with a particular emphasis on:
# 1. **Definition of Self-Assembly**: Both messages define self-assembly as the process where components organize into ordered structures without external direction.
# 2. **Explanation of the Process**: The idea that self-assembly involves pre-existing components forming organized structures due to local interactions is present in both messages.
#
# Additional shared details include specific terms such as:
# - The disordered system transitioning into an organized structure.
# - The underlying principles of how these assemblies occur naturally, pertinent to both molecular and broader contexts.
# - Mention of factors influencing self-assembly, such as local interactions (in the first message) and forces like binding and hydrophobicity (in the second message).
#
# This comprehensive overlap constitutes more than half of the content of both messages.
#
# New message:
# ### Summary:
# The slide explains the concept of self-assembly, categorizing it into static and dynamic types.
#
# ### Concepts and Terms:
# 1. **Self-assembly**: The process where components organize into ordered structures without external direction.
# 2. **Static self-assembly**: Refers to the formation of ordered states as the system reaches equilibrium, decreasing free energy (\(F = E - TS\)):
#     - \(E\): Enthalpy (total energy)
#     - \(S\): Entropy (measure of disorder)
#     - \(T\): Temperature
#
# 3. **Dynamic self-assembly**: Involves the organization of components into patterns that can evolve over time due to changes in component properties or external stimuli.
#
# ### Notes:
# - **Binding and Hydrophobicity**: Are given as examples of forces driving self-assembly. Binding involves attractive interactions while hydrophobicity refers to the tendency of non-polar substances to avoid water.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide explains the concept of self-assembly, categorizing it into \textit{static} and \textit{dynamic} types.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Self-assembly}: The process where components organize into ordered structures without external direction.\\
# \textbf{Static self-assembly}: Refers to the formation of ordered states as the system reaches equilibrium, decreasing free energy \((F = E - TS)\):
# \begin{itemize}
#     \item \(E\): Enthalpy (total energy)
#     \item \(S\): Entropy (measure of disorder)
#     \item \(T\): Temperature
# \end{itemize}
# \textbf{Dynamic self-assembly}: Involves the organization of components into patterns that can evolve over time due to changes in component properties or external stimuli.
#
# \subsection*{Notes}
#
# - \textbf{Binding and Hydrophobicity}: Are given as examples of forces driving self-assembly. Binding involves attractive interactions while hydrophobicity refers to the tendency of non-polar substances to avoid water.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_3.tex
#
#
#
#
# 1. NO RELEVANT INFORMATION.
#
# The slide is irrelevant.
#
# 1. ### Summary:
# The slide provides examples of molecular assemblies, focusing on lipids (amphiphiles) and their various structural formations.
#
# ### Concepts and Terms:
# 1. **Lipids (Amphiphiles):** Molecules that contain both hydrophilic (water-attracting) heads and hydrophobic (water-repelling) tails.
#    - *Hydrophilic head*: The part of the lipid that is water-attracting.
#    - *Hydrophobic tail*: The part of the lipid that is water-repelling.
#
# 2. **Lipid Assembly:**
#    - Driven by entropy and hydrophobicity, which cause lipids to organize themselves in a way that minimizes free energy.
#
# 3. **Types of Molecular Assemblies:**
#    - **Micelle:** A spherical arrangement of lipids with hydrophobic tails inward and hydrophilic heads outward.
#    - **Cylindrical Micelle:** Similar to micelles but in a cylindrical form.
#    - **Vesicle:** Spherical structures with a lipid bilayer, can encapsulate substances inside.
#    - **Spheres (FCC and BCC):** Face-Centered Cubic and Body-Centered Cubic arrangements, specific to the spatial organization of spherical micelles.
#    - **Hexagonally Packed Cylinders (HEX):** Cylinders arranged in a hexagonal pattern.
#    - **Gyroid:** A complex 3D structure with minimal surfaces and no straight paths.
#    - **Lamellae (LAM):** A layered structure of lipids.
#    - **Modulated Lamellae (MLAM):** Lamellae with a periodic variation.
#    - **Perforated Lamellae (PLAM):** Lamellae that contain pores.
#    - **F-surface** and **P-surface:** Types of cubic bicontinuous structures with specific symmetries and curvatures.
#
# ### Notes:
# - **Entropy:** Refers to the measure of randomness or disorder in a system.
# - **Hydrophobicity:** The tendency to repel water, significant in the self-assembly of lipid molecules.
#
# For more detailed understanding, attending the lecture "Design principles in biomaterials" is recommended, which will delve deeper into lipid-based assemblies.
#
# 2. Comparing slide 4 and slide 5.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide provides examples of molecular assemblies, focusing on lipids (\textit{amphiphiles}) and their various structural formations.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Lipids (Amphiphiles)}: Molecules that contain both hydrophilic (water-attracting) heads and hydrophobic (water-repelling) tails.\\
# \textit{Hydrophilic head}: The part of the lipid that is water-attracting.\\
# \textit{Hydrophobic tail}: The part of the lipid that is water-repelling.
#
# \textbf{Lipid Assembly}: Driven by entropy and hydrophobicity, which cause lipids to organize themselves in a way that minimizes free energy.
#
# \textbf{Types of Molecular Assemblies}:
# \begin{itemize}
#     \item \textbf{Micelle}: A spherical arrangement of lipids with hydrophobic tails inward and hydrophilic heads outward.
#     \item \textbf{Cylindrical Micelle}: Similar to micelles but in a cylindrical form.
#     \item \textbf{Vesicle}: Spherical structures with a lipid bilayer, can encapsulate substances inside.
#     \item \textbf{Spheres (FCC and BCC)}: Face-Centered Cubic and Body-Centered Cubic arrangements, specific to the spatial organization of spherical micelles.
#     \item \textbf{Hexagonally Packed Cylinders (HEX)}: Cylinders arranged in a hexagonal pattern.
#     \item \textbf{Gyroid}: A complex 3D structure with minimal surfaces and no straight paths.
#     \item \textbf{Lamellae (LAM)}: A layered structure of lipids.
#     \item \textbf{Modulated Lamellae (MLAM)}: Lamellae with a periodic variation.
#     \item \textbf{Perforated Lamellae (PLAM)}: Lamellae that contain pores.
#     \item \textbf{F-surface} and \textbf{P-surface}: Types of cubic bicontinuous structures with specific symmetries and curvatures.
# \end{itemize}
#
# \subsection*{Notes:}
#
# - \textbf{Entropy}: Refers to the measure of randomness or disorder in a system.\\
# - \textbf{Hydrophobicity}: The tendency to repel water, significant in the self-assembly of lipid molecules.\\
# For more detailed understanding, attending the lecture \textit{Design principles in biomaterials} is recommended, which will delve deeper into lipid-based assemblies.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_5.tex
#
#
#
#
# 1. ### Summary:
# The slide discusses the creation of multi-layer films using alternating layers of cationic (positively charged) and anionic (negatively charged) polymers. This assembly process is driven by the binding between these oppositely charged polymers.
#
# ### Key Concepts and Terms:
# - **Multi-layer films:** Thin films composed of multiple layers of polymers with alternating charges.
# - **Cationic polymers:** Polymers that carry a positive charge. Examples mentioned:
#   - PLL (poly-L-lysine)
#   - PAH (poly-allylamine-hydrochloride)
# - **Anionic polymers:** Polymers that carry a negative charge. Examples mentioned:
#   - Hyaluronic acid
#   - Heparin
#
# ### Diagram Explanation:
# - **Layer Assembly Process:**
#   1. A polyanion (negatively charged polymer) layer is deposited on a substrate.
#   2. The substrate is washed to remove excess polymer.
#   3. A polycation (positively charged polymer) layer is then deposited.
#   4. The substrate is washed again.
#   5. The layering process is repeated to build the multi-layer structure.
#
# ### Notes:
# - The bottom of the slide poses a relevant question for further exploration: "How can those films be disassembled again?" indicating a future topic or area of study regarding the removal or disassembly of these multi-layer films.
#
# 2. Comparing slide 5 and slide 6.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses the creation of multi-layer films using alternating layers of \textit{cationic} (positively charged) and \textit{anionic} (negatively charged) polymers. This assembly process is driven by the binding between these oppositely charged polymers.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Multi-layer films}: Thin films composed of multiple layers of polymers with alternating charges.\\
# \textbf{Cationic polymers}: Polymers that carry a positive charge. Examples mentioned:
# \begin{itemize}
#     \item PLL (poly-L-lysine)
#     \item PAH (poly-allylamine-hydrochloride)
# \end{itemize}
# \textbf{Anionic polymers}: Polymers that carry a negative charge. Examples mentioned:
# \begin{itemize}
#     \item Hyaluronic acid
#     \item Heparin
# \end{itemize}
#
# \subsection*{Diagrams and Data}
#
# \textbf{Layer Assembly Process}
# \begin{itemize}
#     \item A polyanion (negatively charged polymer) layer is deposited on a substrate.
#     \item The substrate is washed to remove excess polymer.
#     \item A polycation (positively charged polymer) layer is then deposited.
#     \item The substrate is washed again.
#     \item The layering process is repeated to build the multi-layer structure.
# \end{itemize}
#
# \subsection*{Notes:}
#
# - The bottom of the slide poses a relevant question for further exploration: "\textit{How can those films be disassembled again?}" indicating a future topic or area of study regarding the removal or disassembly of these multi-layer films.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_6.tex
#
#
#
#
# 1. **Summary:**
# The slide discusses the properties of multi-layer films based on hyaluronic acid (HA) and poly-L-lysine (PLL).
#
# **Concepts and Data:**
#
# 1. **Combination of PLL with HA Variants:**
#    - The slide studies the combination of PLL with different HA variants.
#    - HA variants include those with various molecular weights (200, 400, and 1300 kDa).
#
# 2. **Deposited Mass:**
#    - Shows that the deposited mass (measured by the frequency shift via QCM - Quartz Crystal Microbalance) increases with the molecular weight of HA used.
#
# 3. **Graph (Top Right):**
#    - The graph shows the frequency shift (ΔF) as a function of the number of HA/PLL bilayers.
#    - Different symbols represent different HA molecular weights.
#    - Higher molecular weight HAs (HA1300) show greater frequency shifts, indicating higher mass deposition.
#
# 4. **Multi-Layer Film Swelling:**
#    - The table provides data on the mass, dry and wet thickness, and swelling percentage of HA and PLL ending films.
#    - HA1300-HA ending shows the highest swelling percentage (~600%).
#    - Wet thickness varies among the combinations, with HA-ending layers exhibiting higher thickness.
#
# 5. **Images of Film Swelling:**
#    - Illustrations (A-D) visualizing the swelling of the films in dry and PBS (phosphate-buffered saline) states.
#    - The images depict different combinations of HA and PLL endings.
#
# **NOTES:**
# - **Importance of QCM:**
#   - QCM is a critical tool for measuring thin film properties as it provides insights into mass changes through frequency shifts.
# - **Relevance in Biomedical Applications:**
#   - Understanding swelling and thickness properties is essential for applications such as drug delivery and tissue engineering.
#
# **Study Reference:**
# Shen et al., Biomacromolecules (2011).
#
# 2. Comparing slide 6 and slide 7.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses the properties of multi-layer films based on hyaluronic acid (HA) and poly-L-lysine (PLL).
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# Combination of PLL with HA Variants: The slide studies the combination of PLL with different HA variants. \\
# HA variants include those with various molecular weights (200, 400, and 1300 kDa).
#
# Deposited Mass: Shows that the deposited mass (measured by the frequency shift via QCM - Quartz Crystal Microbalance) increases with the molecular weight of HA used.
#
# \subsection*{Diagrams and Data}
#
# \textbf{Graph (Top Right)}
#     \begin{itemize}
#         \item The graph shows the frequency shift (\(\Delta F\)) as a function of the number of HA/PLL bilayers.
#         \item Different symbols represent different HA molecular weights.
#         \item Higher molecular weight HAs (HA1300) show greater frequency shifts, indicating higher mass deposition.
#     \end{itemize}
# \textbf{Multi-Layer Film Swelling}
#     \begin{itemize}
#         \item The table provides data on the mass, dry and wet thickness, and swelling percentage of HA and PLL ending films.
#         \item HA1300-HA ending shows the highest swelling percentage (\(\sim 600\%\)).
#         \item Wet thickness varies among the combinations, with HA-ending layers exhibiting higher thickness.
#     \end{itemize}
# \textbf{Images of Film Swelling}
#     \begin{itemize}
#         \item Illustrations (A-D) visualizing the swelling of the films in dry and PBS (phosphate-buffered saline) states.
#         \item The images depict different combinations of HA and PLL endings.
#     \end{itemize}
#
# \subsection*{Notes:}
#
# - \textit{Importance of QCM}: QCM is a critical tool for measuring thin film properties as it provides insights into mass changes through frequency shifts. \\
# - \textit{Relevance in Biomedical Applications}: Understanding swelling and thickness properties is essential for applications such as drug delivery and tissue engineering.
#
# Study Reference: Shen et al., Biomacromolecules (2011).
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_7.tex
#
#
#
#
# 1. ### Summary
# The slide discusses the use of multi-layer films for drug delivery, specifically focusing on the delivery of the anti-tumor drug paclitaxel through a therapeutic dual multilayer system.
#
# ### Relevant Concepts and Terms
# 1. **Multi-layer Films**: These are thin films made by layering different materials, which can be used to control drug delivery.
# 2. **Drug Delivery**: The method by which drugs are transported to their site of action within the body.
# 3. **Paclitaxel**: An anti-tumor drug used to treat various cancers.
# 4. **Layer-by-Layer (LbL) Assembly**: A technique for creating multi-layer films through the sequential deposition of alternating positively and negatively charged layers.
# 5. **Heparin**: An anionic (negatively charged) molecule used in forming the layers.
# 6. **Poly-L-Lysine (PLL)**: A cationic (positively charged) molecule also used in forming the layers.
# 7. **Hydrogel Layer**: A network of polymer chains that can hold a large amount of water, often used for controlled drug release.
# 8. **HA-G-PLGA Nanoparticles**: Biodegradable nanoparticles often used for delivering drugs.
#
# ### Diagrams and Graphs
# - **Schematic Diagram**: Shows the structure and composition of the multi-layer films including a thin heparin hydrogel layer and layers of anionic heparin and cationic PLL.
# - **Drug Loading**: Indicates paclitaxel as the loaded drug within the layers.
# - **Release Graph**: Demonstrates cumulative paclitaxel release over time, comparing different numbers of layers (5, 10, and 15 layers).
#
# ### Notes
# - **Biocompatibility**: The use of biocompatible materials (heparin, PLL, HA-G-PLGA nanoparticles) ensures the system is safe for biomedical applications.
# - **Controlled Release**: The release graph indicates that the number of layers influences the rate and amount of drug release, which can be tailored according to therapeutic needs.
#
# 2. Comparing slide 7 and slide 8.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses the use of multi-layer films for drug delivery, specifically focusing on the delivery of the anti-tumor drug paclitaxel through a therapeutic dual multilayer system.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Multi-layer Films}: These are thin films made by layering different materials, which can be used to control drug delivery.\\
# \textbf{Drug Delivery}: The method by which drugs are transported to their site of action within the body.\\
# \textbf{Paclitaxel}: An anti-tumor drug used to treat various cancers.\\
# \textbf{Layer-by-Layer (LbL) Assembly}: A technique for creating multi-layer films through the sequential deposition of alternating positively and negatively charged layers.\\
# \textbf{Heparin}: An anionic (negatively charged) molecule used in forming the layers.\\
# \textbf{Poly-L-Lysine (PLL)}: A cationic (positively charged) molecule also used in forming the layers.\\
# \textbf{Hydrogel Layer}: A network of polymer chains that can hold a large amount of water, often used for controlled drug release.\\
# \textbf{HA-G-PLGA Nanoparticles}: Biodegradable nanoparticles often used for delivering drugs.
#
# \subsection*{Diagrams and Data}
#
# \textbf{Schematic Diagram}
#     \begin{itemize}
#         \item Shows the structure and composition of the multi-layer films including a thin heparin hydrogel layer and layers of anionic heparin and cationic PLL.
#     \end{itemize}
# \textbf{Drug Loading}
#     \begin{itemize}
#         \item Indicates paclitaxel as the loaded drug within the layers.
#     \end{itemize}
# \textbf{Release Graph}
#     \begin{itemize}
#         \item Demonstrates cumulative paclitaxel release over time, comparing different numbers of layers (5, 10, and 15 layers).
#     \end{itemize}
#
# \subsection*{Notes}
#
# - \textit{Biocompatibility}: The use of biocompatible materials (heparin, PLL, HA-G-PLGA nanoparticles) ensures the system is safe for biomedical applications.\\
# - \textit{Controlled Release}: The release graph indicates that the number of layers influences the rate and amount of drug release, which can be tailored according to therapeutic needs.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_8.tex
#
#
#
#
# 1. ### Summary:
# The slide discusses the formation and stability of mucin-based multi-layer films using mucins and mucin-binding molecules (lectins). It highlights the method and shows data supporting the stability of the films across different pH values and sodium chloride (NaCl) concentrations.
#
# ### Key Concepts and Terms:
# 1. **Mucin (BSM)**: A glycoprotein used as a building block in forming multi-layer films.
# 2. **Lectin (Jacalin)**: A protein that binds specifically to sugars, used here to bind layers of mucin.
# 3. **Substrate**: The base layer on which mucin and lectin layers are built.
# 4. **Poly1/Poly2**: Designations for subsequent layers in the multilayer film.
# 5. **pH and Ionic Strength**: Conditions under which the multilayer films can be formed and maintained.
#
# ### Diagrams and Data Explained:
# - **Formation Diagram**: Shows how mucin and lectin are alternately added to a substrate, forming a multi-layer film. The film thickness is indicated to be around 100 nm for 60 bilayers.
# - **Thickness Graph**: Illustrates the relationship between the number of bilayers and the thickness of the film, showing that as the number of bilayers increases, the thickness also increases, with a coefficient of determination (R²) of 0.943, indicating a strong correlation.
# - **Stability Bar Chart**: Depicts the percentage of remaining fluorescence after treatment in various conditions (different pH values and 5 M NaCl), indicating the stability of the multi-layer film. The film remains stable across a wide range of conditions, with a notable resistance to Debye screening highlighted.
#
# ### Notes:
# - **Debye Screening**: Refers to the reduction of electrostatic interactions in solutions containing high concentrations of ions, such as 5 M NaCl. The films' stability in such conditions suggests robustness in ionic solutions.
#
# 2. Comparing slide 8 and slide 9.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses the formation and stability of mucin-based multi-layer films using mucins and mucin-binding molecules (\textit{lectins}). It highlights the method and shows data supporting the stability of the films across different pH values and sodium chloride (NaCl) concentrations.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Mucin (BSM)}: A glycoprotein used as a building block in forming multi-layer films.\\
# \textbf{Lectin (Jacalin)}: A protein that binds specifically to sugars, used here to bind layers of mucin.\\
# \textbf{Substrate}: The base layer on which mucin and lectin layers are built.\\
# \textbf{Poly1/Poly2}: Designations for subsequent layers in the multilayer film.\\
# \textbf{pH and Ionic Strength}: Conditions under which the multilayer films can be formed and maintained.
#
# \subsection*{Diagrams and Data}
#
# \textbf{Formation Diagram}
#     \begin{itemize}
#         \item Shows how mucin and lectin are alternately added to a substrate, forming a multi-layer film.
#         \item The film thickness is indicated to be around 100 nm for 60 bilayers.
#     \end{itemize}
# \textbf{Thickness Graph}
#     \begin{itemize}
#         \item Illustrates the relationship between the number of bilayers and the thickness of the film.
#         \item As the number of bilayers increases, the thickness also increases, with a coefficient of determination (R\textsuperscript{2}) of 0.943, indicating a strong correlation.
#     \end{itemize}
# \textbf{Stability Bar Chart}
#     \begin{itemize}
#         \item Depicts the percentage of remaining fluorescence after treatment in various conditions (different pH values and 5 M NaCl).
#         \item Indicates the stability of the multi-layer film.
#         \item The film remains stable across a wide range of conditions, with a notable resistance to Debye screening highlighted.
#     \end{itemize}
#
# \subsection*{Notes:}
#
# - \textbf{Debye Screening}: Refers to the reduction of electrostatic interactions in solutions containing high concentrations of ions, such as 5 M NaCl. The films' stability in such conditions suggests robustness in ionic solutions.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_9.tex
#
#
#
#
# 1. **Summary:**
# The slide discusses the controlled disassembly of mucin multi-layer films using melibiose.
#
# **Explanation:**
# - **Concept:** The slide presents an idea for disassembling mucin multi-layer films by using a second molecule (melibiose) to remove the film-stabilizing component, triggering film disassembly.
# - **Melibiose:** A disaccharide (composed of two monosaccharide units) that acts similarly to a pair of scissors to cut or break down components within the film.
# - **Experiment:** Mucin/lectin films were treated with 100mM melibiose at 37°C for 1 hour, causing the films to disassemble.
# - **Diagram:**
#   - Shows the structure before and after treatment with melibiose.
#   - Illustrates the transition from a stable film to an unstructured state.
# - **Graph:** Displays the percentage of remaining fluorescence after treatment under various conditions (different pH levels, buffer types, and NaCl concentrations). The results indicate that melibiose in PBS at pH 7.4 effectively reduces fluorescence, demonstrating successful film disassembly.
#
# **Notes:**
# - The concept demonstrates how specific interactions can be disrupted using small molecules to control the stability of multi-layer films, a principle that can be applied in various fields such as biomedicine and material science.
# - Reference: Polak et al., Biomacromolecules (2014).
#
# 2. Comparing slide 9 and slide 10.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses the controlled disassembly of mucin multi-layer films using melibiose.
#
# \section*{Explanation}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Concept:} The slide presents an idea for disassembling mucin multi-layer films by using a second molecule (\textit{melibiose}) to remove the film-stabilizing component, triggering film disassembly.\\
# \textbf{Melibiose:} A disaccharide (composed of two monosaccharide units) that acts similarly to a pair of scissors to cut or break down components within the film.\\
# \textbf{Experiment:} Mucin/lectin films were treated with 100mM melibiose at 37\textdegree C for 1 hour, causing the films to disassemble.
#
# \subsection*{Diagrams and Data}
#
# \textbf{Diagram:}
#     \begin{itemize}
#         \item Shows the structure before and after treatment with melibiose.
#         \item Illustrates the transition from a stable film to an unstructured state.
#     \end{itemize}
# \textbf{Graph:}
#     \begin{itemize}
#         \item Displays the percentage of remaining fluorescence after treatment under various conditions (different pH levels, buffer types, and NaCl concentrations).
#         \item The results indicate that melibiose in PBS at pH 7.4 effectively reduces fluorescence, demonstrating successful film disassembly.
#     \end{itemize}
#
# \subsection*{Notes}
#
# - The concept demonstrates how specific interactions can be disrupted using small molecules to control the stability of multi-layer films, a principle that can be applied in various fields such as biomedicine and material science.\\
# - Reference: Polak et al., Biomacromolecules (2014).
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_10.tex
#
#
#
#
# 1. ### Slide Summary:
#
# The slide explains the process of drug release from condensed mucin films on implant surfaces and presents data comparing triggered and untriggered release efficiencies over time.
#
# ### Concepts and Terms:
#
# 1. **Condensed Mucin Films:** These are films composed of mucin proteins, which can be condensed and loaded with drug molecules.
#
# 2. **Polymer Coating:** A layer applied to the implant surface which interacts with the drug molecules.
#
# 3. **Trigger Mechanism:** The use of glycerol and stabilizing ions to compact the polymer coating, followed by exposure to physiological NaCl concentrations, which causes the drug to be released.
#
# 4. **Cumulative Release Graphs:** Illustrates the amount of drug released over time. Two graphs are presented:
#    - **Top Graph:** Shows cumulative VAN (presumably Vancomycin) release.
#    - **Bottom Graph:** Shows cumulative TLT (a different drug) release.
#    - **Triggered vs. Untriggered:** Data comparison for conditions that induce drug release ("triggered") and those that do not ("untriggered").
#
# ### Relevant Explanations:
#
# - The diagrams at the top of the slide detail the steps of drug release:
#   1. **Implant Surface:** Initially, the drug molecules are within a polymer coating on an implant surface.
#   2. **Addition of Glycerol and Stabilizing Ions:** This causes the polymer coating to compact and load with the drug.
#   3. **Exposure to NaCl:** Mimicking physiological conditions, the polymer expands, leading to the liberation (release) of the drug molecules.
#
# - **Cumulative Release Graphs:**
#   - The Y-axis measures the cumulative drug release in mg/mL, while the X-axis represents time in hours.
#   - In both graphs, it's evident that the triggered release (indicated by the black bars) is significantly higher than the untriggered release (white bars) over the observed time.
#
# ### Notes:
#
# - The use of glycerol and stabilizing ions followed by exposure to physiological NaCl concentrations creates a controlled release mechanism for the drugs from the implant surface.
# - Understanding the efficiency and optimization of drug release systems in biomedical implants can lead to more effective treatments and better patient outcomes.
#
#
# 2. Comparing slide 10 and slide 11.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide explains the process of drug release from condensed mucin films on implant surfaces and presents data comparing triggered and untriggered release efficiencies over time.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Condensed Mucin Films:} These are films composed of mucin proteins, which can be condensed and loaded with drug molecules.\\
# \textbf{Polymer Coating:} A layer applied to the implant surface which interacts with the drug molecules.\\
# \textbf{Trigger Mechanism:} The use of glycerol and stabilizing ions to compact the polymer coating, followed by exposure to physiological NaCl concentrations, which causes the drug to be released.\\
# \textbf{Cumulative Release Graphs:} Illustrates the amount of drug released over time. Two graphs are presented:
# \begin{itemize}
#     \item \textit{Top Graph:} Shows cumulative VAN (presumably Vancomycin) release.
#     \item \textit{Bottom Graph:} Shows cumulative TLT (a different drug) release.
#     \item \textit{Triggered vs. Untriggered:} Data comparison for conditions that induce drug release ("triggered") and those that do not ("untriggered").
# \end{itemize}
#
# \subsection*{Diagrams and Data}
#
# \textbf{Drug Release Steps}
# \begin{itemize}
#     \item \textit{Implant Surface:} Initially, the drug molecules are within a polymer coating on an implant surface.
#     \item \textit{Addition of Glycerol and Stabilizing Ions:} This causes the polymer coating to compact and load with the drug.
#     \item \textit{Exposure to NaCl:} Mimicking physiological conditions, the polymer expands, leading to the liberation (release) of the drug molecules.
# \end{itemize}
# \textbf{Cumulative Release Graphs}
# \begin{itemize}
#     \item The Y-axis measures the cumulative drug release in mg/mL, while the X-axis represents time in hours.
#     \item In both graphs, it is evident that the triggered release (indicated by the black bars) is significantly higher than the untriggered release (white bars) over the observed time.
# \end{itemize}
#
# \subsection*{Notes:}
#
# - The use of glycerol and stabilizing ions followed by exposure to physiological NaCl concentrations creates a controlled release mechanism for the drugs from the implant surface.\\
# - Understanding the efficiency and optimization of drug release systems in biomedical implants can lead to more effective treatments and better patient outcomes.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_11.tex
#
#
#
#
# 1. ### Summary
#
# The slide discusses a method for controlled drug release from multi-layered mucin films using a combination of techniques.
#
# ### Relevant Concepts
#
# 1. **Drug Release Mechanisms:**
#    - **1st Dosing Trigger:** Activated upon tissue contact.
#    - **2nd Dosing Trigger:** Activated upon an increase in temperature.
#    - **Long-Term Protection:** Provides lubrication and sustained protection.
#
# 2. **Techniques:**
#    - **Molecular Scissors:** May involve enzymes or chemicals that can cleave specific bonds within the drug-delivery film.
#    - **Ion-Driven Film Decompaction:** Utilizes ionic interactions to break apart the film structure, effectively releasing the drug.
#
# ### Diagrams
#
# - The diagram illustrates the multi-layered structure of mucin, showing the sequential drug release mechanism upon tissue contact and temperature change, aimed at ensuring prolonged efficacy and protection.
#
# ### Notes
#
# - This approach can be essential in designing effective drug delivery systems that offer precise control over the timing and rate of drug release.
# - The concept is particularly relevant to biomedical applications where targeted delivery is crucial.
#
# (Source: Kimna et al., Advanced Materials Interfaces, 2020)
#
# 2. Comparing slide 11 and slide 12.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses a method for controlled drug release from multi-layered mucin films using a combination of techniques.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Drug Release Mechanisms:} \\
# \textit{1st Dosing Trigger:} Activated upon tissue contact. \\
# \textit{2nd Dosing Trigger:} Activated upon an increase in temperature. \\
# \textit{Long-Term Protection:} Provides lubrication and sustained protection.
#
# \textbf{Techniques:} \\
# \textit{Molecular Scissors:} May involve enzymes or chemicals that can cleave specific bonds within the drug-delivery film. \\
# \textit{Ion-Driven Film Decompaction:} Utilizes ionic interactions to break apart the film structure, effectively releasing the drug.
#
# \subsection*{Diagrams and Data}
#
# \textbf{Structure Illustration}
#     \begin{itemize}
#         \item Multi-layered structure of mucin
#         \item Sequential drug release mechanism upon tissue contact and temperature change
#     \end{itemize}
#
# \textbf{Prolonged Efficacy}
#     \begin{itemize}
#         \item Ensured prolonged efficacy
#         \item Sustained protection
#     \end{itemize}
#
# \subsection*{Notes:}
#
# - This approach can be essential in designing effective drug delivery systems that offer precise control over the timing and rate of drug release. \\
# - The concept is particularly relevant to biomedical applications where targeted delivery is crucial.
#
# (Source: Kimna et al., Advanced Materials Interfaces, 2020)
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_12.tex
#
#
#
#
# 1. ### Summary:
# This slide explains the process of assembling a mucin multi-layer system using different components such as mucin, DOPA, and lectin.
#
# ### Explanation:
# - **Mucin Layers**: The multi-layer system is formed primarily using mucin layers, as indicated in the stages 1, 3, and 5 on the graph.
# - **DOPA**: Stage 2 involves the addition of DOPA, a component known for its adhesive properties.
# - **Lectin**: Stage 4 entails the inclusion of lectin, which can bind specific sugar molecules.
# - **Graph Analysis**: The graph plots frequency change (Δf in Hz) over time (hours). Each significant drop in frequency corresponds to the addition of a new layer, indicating successful adsorption of the respective materials.
# - **Further Assembly**: The diagram on the right illustrates the step-by-step assembly of the layers, with the different components labeled clearly.
#
# ### Diagram Components:
# - **Mucin**: Depicted in blue
# - **Lectin**: Shown in white
# - **DOPA**: Indicated by black squiggly lines
# - **GlcNAc**: Represented as green circles, indicating sugar molecules typically bound by lectin.
#
# ### Notes:
# - **Dynamic Nature**: The frequency shifts shown in the graph reveal the dynamic interactions between these materials during the assembly process.
# - **Application**: This multi-layer system could be used in designing advanced biomaterials, useful in various medical and industrial applications.
#
# 2. Comparing slide 12 and slide 13.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# This slide explains the process of assembling a mucin multi-layer system using different components such as mucin, DOPA, and lectin.
#
# \section*{Explanation}
#
# \subsection*{Mucin Layers}
#
# The multi-layer system is formed primarily using mucin layers, as indicated in the stages 1, 3, and 5 on the graph.
#
# \subsection*{DOPA}
#
# Stage 2 involves the addition of DOPA, a component known for its adhesive properties.
#
# \subsection*{Lectin}
#
# Stage 4 entails the inclusion of lectin, which can bind specific sugar molecules.
#
# \subsection*{Graph Analysis}
#
# The graph plots frequency change (\(\Delta f\) in Hz) over time (hours). Each significant drop in frequency corresponds to the addition of a new layer, indicating successful adsorption of the respective materials.
#
# \subsection*{Further Assembly}
#
# The diagram on the right illustrates the step-by-step assembly of the layers, with the different components labeled clearly.
#
# \section*{Diagram Components}
#
# \textbf{Mucin}
#     \begin{itemize}
#         \item Depicted in blue
#     \end{itemize}
# \textbf{Lectin}
#     \begin{itemize}
#         \item Shown in white
#     \end{itemize}
# \textbf{DOPA}
#     \begin{itemize}
#         \item Indicated by black squiggly lines
#     \end{itemize}
# \textbf{GlcNAc}
#     \begin{itemize}
#         \item Represented as green circles, indicating sugar molecules typically bound by lectin
#     \end{itemize}
#
# \section*{Notes}
#
# - \textit{Dynamic Nature}: The frequency shifts shown in the graph reveal the dynamic interactions between these materials during the assembly process.\\
# - \textit{Application}: This multi-layer system could be used in designing advanced biomaterials, useful in various medical and industrial applications.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_13.tex
#
#
#
#
# 1. ### Summary:
#
# This slide discusses the release of drugs from mucin multi-layers, focusing on the behavior of empty and filled vesicles under varying temperatures.
#
# ### Concepts and Terms:
#
# 1. **Mucin Multi-Layers**: Layers formed by mucin proteins that serve as a barrier while allowing controlled release of incorporated substances such as drugs.
# 2. **Vesicles**: Small membrane-bound sacs involved in transporting substances within biological systems.
# 3. **Empty Vesicles**: Shown with open symbols (no scissor molecules).
# 4. **Filled Vesicles**: Shown with full symbols; contain molecular scissors (enzymes or other substances capable of breaking bonds) that get activated at higher temperatures.
# 5. **Higher T**: Higher temperature condition where the molecular scissors are released and activated.
#
# ### Diagram Explanation:
#
# 1. **Top Right Illustrations**:
#    - **Left Illustration**: Represents unloaded liposomes in condensed layers of TCL (Transmembrane Command Layer).
#    - **Right Illustration**: Shows liposomes loaded with GlcNAc (N-acetylglucosamine), indicating molecular scissors being enclosed.
#
# 2. **Graph**:
#    - **X-axis (time [h])**: Shows the time in hours over several days.
#    - **Left Y-axis (cumulative release [mg/mL])**: Shows the cumulative drug release concentration.
#    - **Right Y-axis (release efficiency [%])**: Indicates the efficiency of drug release.
#    - **Black and Red Circles**: Designate data points for temperatures 37°C and 40°C respectively.
#    - **Dashed and Solid Lines**: Indicate the general trend of cumulative release for both temperature conditions.
#
# ### Notes:
#
# - **Effect of Temperature**: The graph shows that at 40°C (red circles and line), the drug release is significantly higher compared to 37°C.
# - **NaCl Addition**: The point where NaCl is added is marked, possibly to study its effect on drug release dynamics.
# - The molecular scissors in filled vesicles become active at higher temperatures, thus increasing drug release efficiency.
#
# Understanding this slide provides insights into the controlled release mechanisms employed in drug delivery systems using mucin multi-layers and the impact of temperature on these processes.
#
# 2. Comparing slide 13 and slide 14.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# This slide discusses the release of drugs from mucin multi-layers, focusing on the behavior of empty and filled vesicles under varying temperatures.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Mucin Multi-Layers}: Layers formed by mucin proteins that serve as a barrier while allowing controlled release of incorporated substances such as drugs. \\
# \textbf{Vesicles}: Small membrane-bound sacs involved in transporting substances within biological systems. \\
# \textbf{Empty Vesicles}: Shown with open symbols (no scissor molecules). \\
# \textbf{Filled Vesicles}: Shown with full symbols; contain molecular scissors (enzymes or other substances capable of breaking bonds) that get activated at higher temperatures. \\
# \textbf{Higher T}: Higher temperature condition where the molecular scissors are released and activated.
#
# \subsection*{Diagrams and Data}
#
# \textbf{Top Right Illustrations}
# \begin{itemize}
#     \item \textit{Left Illustration}: Represents unloaded liposomes in condensed layers of TCL (Transmembrane Command Layer).
#     \item \textit{Right Illustration}: Shows liposomes loaded with GlcNAc (N-acetylglucosamine), indicating molecular scissors being enclosed.
# \end{itemize}
#
# \textbf{Graph}
# \begin{itemize}
#     \item \textit{X-axis (time [h])}: Shows the time in hours over several days.
#     \item \textit{Left Y-axis (cumulative release [mg/mL])}: Shows the cumulative drug release concentration.
#     \item \textit{Right Y-axis (release efficiency [\%])}: Indicates the efficiency of drug release.
#     \item \textit{Black and Red Circles}: Designate data points for temperatures 37\degree C and 40\degree C respectively.
#     \item \textit{Dashed and Solid Lines}: Indicate the general trend of cumulative release for both temperature conditions.
# \end{itemize}
#
# \subsection*{Notes}
#
# - \textbf{Effect of Temperature}: The graph shows that at 40\degree C (red circles and line), the drug release is significantly higher compared to 37\degree C.\\
# - \textbf{NaCl Addition}: The point where NaCl is added is marked, possibly to study its effect on drug release dynamics.\\
# - The molecular scissors in filled vesicles become active at higher temperatures, thus increasing drug release efficiency.
#
# Understanding this slide provides insights into the controlled release mechanisms employed in drug delivery systems using mucin multi-layers and the impact of temperature on these processes.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_14.tex
#
#
#
#
# 1. ### Summary
# The slide discusses fibers in the cytoskeleton of eukaryotic cells, which provide mechanical properties to the cell. It includes images of actin, microtubules, and intermediate filaments.
#
# ### Key Concepts and Terms
# 1. **Fibers in the Cytoskeleton:**
#    - **Definition:** Fibers in the cytoskeleton are structural components in eukaryotic cells that provide mechanical support.
#    - **Types of Fibers:** Actin, microtubules, and intermediate filaments.
#
# 2. **Actin:**
#    - **Description:** Actin fibers are depicted in red in the bottom left image. These fibers are thin and flexible and play a crucial role in cell movement and shape.
#
# 3. **Microtubules:**
#    - **Description:** Microtubules, shown in green in the middle image, are larger, rigid fibers that help maintain cell shape and facilitate intracellular transport.
#    - **Highlighted Text:** Arrows in the image indicate the presence and organization of microtubules within the cells.
#
# 4. **Intermediate Filaments:**
#    - **Description:** Intermediate filaments are depicted in the blue image on the bottom right. They provide tensile strength to the cell, helping it withstand mechanical stress.
#
# ### Notes
# - **Assembly Mechanism:** The assembly of these fibers is driven by a combination of hydrophobicity and binding properties.
# - **Mechanical Properties:** The cytoskeleton fibers collectively provide structural support, maintain cell shape, and enable various cellular movements.
#
# By understanding the structural and functional aspects of these fibers, one can appreciate the dynamic nature of cellular mechanics essential for various biological processes.
#
# 2. Comparing slide 14 and slide 15.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# ...
#        \item \textit{Bleached CNF}: Least browning and spoilage; the best in extending freshness up to Day 14.
#    \end{itemize}
#
# \subsection*{Notes}
#
# - The application of CNF coatings significantly delays the ripening and browning processes in bananas.\\
# - Bleached CNF appears to be more effective than unbleached CNF in extending shelf-life.\\
# - This technique can potentially be applied to other perishable items like cucumbers, as implied by the slide.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_71.tex
#
#
#
#
# 1. NO RELEVANT INFORMATION
#
# The slide is irrelevant.
#
# 1. **Summary of Slide Content:**
# The slide discusses a bachelor thesis/term paper focused on increasing the stability of alginate foils by adding hydrophobic coatings. It covers materials for coatings, methods to apply these coatings, and experimental characterization techniques.
#
# **Relevant Concepts and Terms:**
#
# 1. **Alginate Foils:**
#    - Thin films made from alginate, a biopolymer derived from seaweed, often used in biomedical and food applications due to its biocompatibility and biodegradability.
#
# 2. **Hydrophobic Coatings:**
#    - Coatings that repel water, enhancing the stability of alginate foils by preventing swelling and degradation in aqueous environments.
#
# 3. **Material Options for Coatings:**
#    - **Bee Wax:** A natural wax produced by honey bees, providing a hydrophobic barrier.
#    - **Lipids:** Organic compounds that are hydrophobic, used to create water-repellent surfaces.
#
# 4. **Process Options for Creating Coated Alginate Foils:**
#    - **Multi-step Casting:** A process involving multiple layers or stages to apply coatings.
#    - **Painting:** Direct application of a coating onto the foil surface.
#    - **Surface Activation (optional):** Techniques like DOPA (dihydroxyphenylalanine) or plasma treatment to enhance coating adhesion.
#
# 5. **Experimental Characterizations:**
#    - **Contact Angle Measurements:** Evaluates the wettability of the coated surface by measuring the angle formed by a water droplet.
#    - **Degradation Kinetics:** Studies the breakdown or degradation rate of the coated alginate foils over time.
#    - **Mechanical Properties:** Investigates the strength and flexibility of the coated foils.
#
# **NOTES:**
# - Understanding the contact angle is crucial to determine the hydrophobicity of the coatings.
# - Degradation kinetics help in predicting the lifespan and stability of the coated foils in various environments.
# - Enhancing mechanical properties ensures the coated foils are durable and suitable for practical applications.
#
# 2. Comparing slide 72 and slide 73.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses a bachelor thesis/term paper focused on increasing the stability of alginate foils by adding hydrophobic coatings. It covers materials for coatings, methods to apply these coatings, and experimental characterization techniques.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Alginate Foils}: Thin films made from alginate, a biopolymer derived from seaweed, often used in biomedical and food applications due to its biocompatibility and biodegradability.\\
# \textbf{Hydrophobic Coatings}: Coatings that repel water, enhancing the stability of alginate foils by preventing swelling and degradation in aqueous environments.\\
# \textbf{Material Options for Coatings}:
# \begin{itemize}
#     \item \textit{Bee Wax}: A natural wax produced by honey bees, providing a hydrophobic barrier.
#     \item \textit{Lipids}: Organic compounds that are hydrophobic, used to create water-repellent surfaces.
# \end{itemize}
# \textbf{Process Options for Creating Coated Alginate Foils}:
# \begin{itemize}
#     \item \textit{Multi-step Casting}: A process involving multiple layers or stages to apply coatings.
#     \item \textit{Painting}: Direct application of a coating onto the foil surface.
#     \item \textit{Surface Activation (optional)}: Techniques like DOPA (dihydroxyphenylalanine) or plasma treatment to enhance coating adhesion.
# \end{itemize}
# \textbf{Experimental Characterizations}:
# \begin{itemize}
#     \item \textit{Contact Angle Measurements}: Evaluates the wettability of the coated surface by measuring the angle formed by a water droplet.
#     \item \textit{Degradation Kinetics}: Studies the breakdown or degradation rate of the coated alginate foils over time.
#     \item \textit{Mechanical Properties}: Investigates the strength and flexibility of the coated foils.
# \end{itemize}
#
# \subsection*{Notes:}
#
# - Understanding the contact angle is crucial to determine the hydrophobicity of the coatings.\\
# - Degradation kinetics help in predicting the lifespan and stability of the coated foils in various environments.\\
# - Enhancing mechanical properties ensures the coated foils are durable and suitable for practical applications.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_73.tex
#
#
#
#
# 1. ### Summary:
#
# The slide discusses the investigation of friction and wear formation at mechanical and topographical discontinuities in different grades of osteoarthritis (OA). The study aims to mimic the transitions between OA grades 1 to 2, and 2 to 3 using PDMS-based samples with variable mechanical properties.
#
# ### Relevant Concepts and Terms:
#
# 1. **Osteoarthritis (OA) Grades**:
#    - **Grade I**: Minimal wear.
#    - **Grade II**: Slight wear with surface irregularities.
#    - **Grade III**: Moderate breakdown of cartilage.
#    - **Grade IV**: Severe degradation.
#
# 2. **PDMS-based Samples**:
#    - Samples made from Polydimethylsiloxane (PDMS) are used to model different mechanical and topographical properties.
#    - Variations are in stiffness, roughness, and friction.
#
# 3. **Friction and Wear Analysis**:
#    - The diagram shows the coefficient of friction versus angle for materials like PTFE and PDMS.
#    - Analysis of surface wear includes microscopy images (b) and topographical measurements (c).
#
# ### Diagrams and Graphs:
# - **OA Grade Illustrations (a-d)**: Visual depictions of OA severity and corresponding mechanical effects.
# - **Coefficient of friction graph (bottom left)**: Shows friction's dependency on angle, with data points representing different material properties.
# - **Surface Micrograph and Topography (b and c)**: Images showing the microscale wear patterns and surface roughness, respectively.
#
# ### NOTES:
# - The study explores how mechanical and topographical changes in materials can simulate different stages of osteoarthritis, aiding in understanding of wear mechanisms and material design for biomedical applications.
#
# 2. Comparing slide 73 and slide 74.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide discusses the investigation of friction and wear formation at mechanical and topographical discontinuities in different grades of osteoarthritis (OA). The study aims to mimic the transitions between OA grades 1 to 2, and 2 to 3 using PDMS-based samples with variable mechanical properties.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Osteoarthritis (OA) Grades}:
# Grade I: Minimal wear.\\
# Grade II: Slight wear with surface irregularities.\\
# Grade III: Moderate breakdown of cartilage.\\
# Grade IV: Severe degradation.
#
# \textbf{PDMS-based Samples}:
# Samples made from Polydimethylsiloxane (PDMS) are used to model different mechanical and topographical properties.\\
# Variations are in stiffness, roughness, and friction.
#
# \textbf{Friction and Wear Analysis}:
# The diagram shows the coefficient of friction versus angle for materials like PTFE and PDMS.\\
# Analysis of surface wear includes microscopy images (b) and topographical measurements (c).
#
# \subsection*{Diagrams and Data}
#
# \textbf{OA Grade Illustrations (a-d)}
#     \begin{itemize}
#         \item Visual depictions of OA severity and corresponding mechanical effects.
#     \end{itemize}
# \textbf{Coefficient of friction graph (bottom left)}
#     \begin{itemize}
#         \item Shows friction's dependency on angle, with data points representing different material properties.
#     \end{itemize}
# \textbf{Surface Micrograph and Topography (b and c)}
#     \begin{itemize}
#         \item Images showing the microscale wear patterns and surface roughness, respectively.
#     \end{itemize}
#
# \subsection*{Notes:}
#
# - The study explores how mechanical and topographical changes in materials can simulate different stages of osteoarthritis, aiding in understanding of wear mechanisms and material design for biomedical applications.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_74.tex
#
#
#
#
# 1. NO RELEVANT INFORMATION.
#
# The slide is irrelevant.
#
# 1. ### Summary
# The slide introduces the lecture on "Design Principles in Biomatter – Nature as an Engineer," outlining the key topics to be covered. These include the four classes of molecules in biological matter, self-assembly, diffusion, selective permeability, signal transduction, and light absorption and conversion.
#
# ### Concepts and Terms
# - **Four Classes of Molecules**: These constitute biological matter and will be discussed.
# - **Self-Assembly**: A process where molecules spontaneously form organized structures without human intervention.
# - **Diffusion**: A key transport mechanism in bio-matter that involves the movement of molecules from high concentration areas to low concentration areas.
# - **Selective Permeability Filters**: Microscopic designs that allow certain molecules to pass through while blocking others, key for maintaining gradients of ions or protons.
# - **Signal Transduction**: The process by which a signal is transmitted through a cell as a series of molecular events, particularly in neurons.
# - **Light Absorption and Conversion**: A molecular principle where light energy is absorbed and converted into chemical energy, such as in photosynthesis.
#
# ### Notes
# - **SWS** stands for Semesterwochenstunden (weekly hours per semester).
# - **ECTS** stands for European Credit Transfer and Accumulation System, indicating the credit value of the course.
# - Understanding these concepts is integral for applying the principles of nature to engineering biomaterials and systems.
#
# 2. Comparing slide 75 and slide 76.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# The slide introduces the lecture on "Design Principles in Biomatter – Nature as an Engineer," outlining the key topics to be covered. These include the four classes of molecules in biological matter, self-assembly, diffusion, selective permeability, signal transduction, and light absorption and conversion.
#
# \section*{Explanations}
#
# \subsection*{Concepts and Terms}
#
# \textbf{Four Classes of Molecules}: These constitute biological matter and will be discussed.\\
# \textbf{Self-Assembly}: A process where molecules spontaneously form organized structures without human intervention.\\
# \textbf{Diffusion}: A key transport mechanism in bio-matter that involves the movement of molecules from high concentration areas to low concentration areas.\\
# \textbf{Selective Permeability Filters}: Microscopic designs that allow certain molecules to pass through while blocking others, key for maintaining gradients of ions or protons.\\
# \textbf{Signal Transduction}: The process by which a signal is transmitted through a cell as a series of molecular events, particularly in neurons.\\
# \textbf{Light Absorption and Conversion}: A molecular principle where light energy is absorbed and converted into chemical energy, such as in photosynthesis.
#
# \subsection*{Notes:}
#
# - \textit{SWS} stands for Semesterwochenstunden (weekly hours per semester)\\
# - \textit{ECTS} stands for European Credit Transfer and Accumulation System, indicating the credit value of the course.\\
# - Understanding these concepts is integral for applying the principles of nature to engineering biomaterials and systems.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_76.tex
#
#
#
#
# 1. ### Summary:
# This slide gives an overview of a module titled "Biomaterial Characterization for Engineers," detailing the scientific methods suitable for characterizing the structure and mechanics of biomaterials.
#
# ### Key Concepts:
#
# 1. **Imaging Techniques**:
#    - **Light Microscopy**: Uses light to magnify samples and is discussed for its application in biomaterial structure elucidation.
#    - **Electron Microscopy**: Utilizes electron beams to achieve higher resolution images.
#    - **Near-field Microscopy**: Allows imaging beyond the diffraction limit of light.
#    - **Scanning Force Microscopy (Raster-Kraft-Mikroskopie)**: Provides detailed surface topography.
#
# 2. **Techniques for Assessing Viscoelastic/Tribological Material Properties**:
#    - Methods for measuring mechanical properties such as elasticity and friction.
#    - Discussion around specific measurement setups appropriate for these analyses.
#
# 3. **Lithographic Microstructuring Techniques**:
#    - Techniques for creating microstructures in materials, crucial for various applications.
#    - Combination with optical or mechanical methods for applications such as microfluidics in "lab on a chip" technologies.
#
# ### Diagram:
# - Pie chart indicating the module's focus areas:
#   - Engineering
#   - Physics
#   - Biology
#
# ### Notes:
# - The module is 3 SWS (Semesterwochenstunden) and 5 ECTS (European Credit Transfer and Accumulation System) credits.
# - The teaching language is German.
#
# This module emphasizes interdisciplinary approaches, integrating engineering, physics, and biology aspects for a comprehensive understanding of biomaterials.
#
# 2. Comparing slide 76 and slide 77.
#
# There is no overlap in content.
#
# 3. \begin{document}
#
# \maketitle
#
# \section*{Summary}
#
# This slide gives an overview of a module titled \textit{Biomaterial Characterization for Engineers}, detailing the scientific methods suitable for characterizing the structure and mechanics of biomaterials.
#
# \section*{Explanations}
#
# \subsection*{Key Concepts}
#
# \textbf{Imaging Techniques}:
# - \textit{Light Microscopy}: Uses light to magnify samples and is discussed for its application in biomaterial structure elucidation.\\
# - \textit{Electron Microscopy}: Utilizes electron beams to achieve higher resolution images.\\
# - \textit{Near-field Microscopy}: Allows imaging beyond the diffraction limit of light.\\
# - \textit{Scanning Force Microscopy (Raster-Kraft-Mikroskopie)}: Provides detailed surface topography.
#
# \textbf{Techniques for Assessing Viscoelastic/Tribological Material Properties}:
# - Methods for measuring mechanical properties such as elasticity and friction.\\
# - Discussion around specific measurement setups appropriate for these analyses.
#
# \textbf{Lithographic Microstructuring Techniques}:
# - Techniques for creating microstructures in materials, crucial for various applications.\\
# - Combination with optical or mechanical methods for applications such as microfluidics in "lab on a chip" technologies.
#
# \subsection*{Diagram}
#
# - Pie chart indicating the module's focus areas:
#      \begin{itemize}
#          \item Engineering
#          \item Physics
#          \item Biology
#      \end{itemize}
#
# \subsection*{Notes}
#
# - The module is 3 SWS (Semesterwochenstunden) and 5 ECTS (European Credit Transfer and Accumulation System) credits.\\
# - The teaching language is German.\\
# - This module emphasizes interdisciplinary approaches, integrating engineering, physics, and biology aspects for a comprehensive understanding of biomaterials.
#
# \end{document}
#
# The LaTeX file has been created at: C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials\document_77.tex
#
#
#
#
# Skipped slides: [1, 4, 31, 32, 34, 72, 75]
# Overlapping slides: ['2, 3', '15, 16', '16, 17', '21, 22', '24, 25', '28, 29', '57, 58', '68, 69', '69, 70']

# %%
skipped_slides = [1, 4, 31, 32, 34, 72, 75] 
skipped_slides = skipped_slides.append(i for i in range(1, 24) if i not in [1, 4, 31, 32, 34, 72, 75] )
slide_numbers = [i for i in range(1, 78)]
path_to_pdf = rf"C:\Users\ACER\Downloads\5_Dynamic_materials.pdf"
theme = "DYNAMIC MATERIALS"
path_to_tex = rf"C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials"
path_to_LaTeX = rf"C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\Temp_Test_File_Dynamic_Materials"

slides_to_convert = remove_skipped_slides(slide_numbers, skipped_slides)

for index in slides_to_convert:
    try:
        #Define file paths
        output_directory = path_to_LaTeX
        latex_file_path = os.path.join(path_to_tex, f'document_{index}.tex')
        pdf_file_path = os.path.join(output_directory, f'document_{index}.pdf')
        
        # Compile the LaTeX file to PDF using pdflatex
        xelatex_path = rf"C:\Users\ACER\AppData\Local\Programs\MiKTeX\miktex\bin\x64\xelatex.exe"
        result = subprocess.run([xelatex_path, '-output-directory', output_directory, latex_file_path], capture_output=True, text=True, check=True)

        print(f"The PDF has been created at: {pdf_file_path}")
        print("pdflatex output:", result.stdout)
        print("pdflatex errors:", result.stderr)

    except subprocess.CalledProcessError as e:
        print(f"Error occurred while running pdflatex: {e}")
        print(e.stdout)
        print(e.stderr)
    except Exception as e:
        print(f"An error occurred: {e}")
        
combine_pdfs(path_to_LaTeX, path_to_LaTeX, output_filename='Notes.pdf')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 9
#       6 path_to_tex = rf"C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\TEX_Dynamic_Materials"
#       7 path_to_LaTeX = rf"C:\Users\ACER\Desktop\Coding\NotesFromSlides_V1\Temp_Test_File_Dynamic_Materials"
# ----> 9 slides_to_convert = remove_skipped_slides(slide_numbers, skipped_slides)
#      11 for index in slides_to_convert:
#      12     try:
#      13         #Define file paths
#
# Cell In[3], line 2, in remove_skipped_slides(slides_to_convert, skipped_slides)
#       1 def remove_skipped_slides(slides_to_convert, skipped_slides):
# ----> 2     return [slide for slide in slides_to_convert if slide not in skipped_slides]
#
# TypeError: argument of type 'NoneType' is not iterable
